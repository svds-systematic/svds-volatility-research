# %%
import yfinance as yf
import pandas as pd
import plotly.express as px
import sys
sys.path.append('..')
from utils.my_models import *

df_yahoo = yf.download('ZN=F', start='2019-01-01', interval='1d')
hv_df = hv_dataframe_fast(df_yahoo, 'ZN=F', 40, halflife_fast=2, ovn_weight=1.0, cc_weight=0.25, mix_mode="blend", beta=0.3, index_coeff=1)

regime_fig = px.line(
    hv_df,
    x=hv_df.index,
    y='EmergencyRegime',
    width=1500,
    height=700,
    title='Emergency Regime'
)
regime_fig.show()
regime_fig.write_html('../charts/emergency_regime.html')
# Out:
# [*********************100%***********************]  1 of 1 completed
